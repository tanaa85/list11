# %% [markdown]
# <a href="https://colab.research.google.com/github/tanaa85/list11/blob/main/Kagglecodetesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/Kaggle/Starbucks/Downloaded/starbucks-menu-nutrition-food1.xlsx
# Out:
# ls: cannot access '/content/drive/MyDrive/Kaggle/Starbucks/Downloaded/starbucks-menu-nutrition-food1.xlsx': No such file or directory

# %%
#здесь вышло не так просто. Оказывается нельзя добавлять список к датафрейму с помощью .append, надо каждой список конвертировать в датафрейм и создавать из них один большой датафрейм с помощью конкетинации
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Kaggle/Starbucks/Downloaded/starbucks_drinkMenu_expanded.csv')
df = df.astype(str)
print('Количество разных символов в starbucks_drinkMenu_expanded.csv')
a = 0
dashes_countlist = []
dashes_sum = 0
dashes_countresultlist = []
df_columns = df.columns.tolist() # список с наименованиями колонок
for i in df_columns: #цикл для создания списка с суммой количества символов в каждой колонке (создан список dash_countresult)
  dash_columnslice = df[i] # здесь происходит слайс колонки
  dash_count = dash_columnslice[a].count('-') #здесь проверяется количество символов в каждой ячейка в колонке df[i]
  dashes_countlist.append(dash_count) # здесь создается список с количеством символов в каждой ячейка колонки df[i]
  dashes_sum = dashes_sum + dashes_countlist[a] # здесь создается сумма количество символов в каждой ячейка колонки df[i]
  a = a+1
  dashes_countresultlist.append(dashes_sum)
a = 0
spaces_countlist = []
spaces_sum = 0
spaces_countresultlist = []
for i in df_columns: #цикл для создания списка с суммой количества символов в каждой колонке (создан список space_countresult)
  space_columnslice = df[i]
  space_count = space_columnslice[a].count(' ')
  spaces_countlist.append(space_count)
  spaces_sum = spaces_sum + spaces_countlist[a]
  a = a+1
  spaces_countresultlist.append(spaces_sum)
a = 0
dots_countlist = []
dots_sum = 0
dots_countresultlist = []
for i in df_columns: #цикл для создания списка с суммой количества символов в каждой колонке (создан список space_countresult)
  dots_columnslice = df[i]
  dots_count = space_columnslice[a].count('.')
  dots_countlist.append(space_count)
  dots_sum = dots_sum + dots_countlist[a]
  a = a+1
  dots_countresultlist.append(dots_sum)
a = 0
commas_countlist = []
commas_sum = 0
commas_countresultlist = []
for i in df_columns: #цикл для создания списка с суммой количества символов в каждой колонке (создан список space_countresult)
  commas_columnslice = df[i]
  commas_count = commas_columnslice[a].count('.')
  commas_countlist.append(commas_count)
  commas_sum = commas_sum + commas_countlist[a]
  a = a+1
  commas_countresultlist.append(commas_sum)
a = 0
isalnum_countlist = []
isalnum_sum = 0
isalnum_countresultlist = []
for i in df_columns: #цикл для создания списка с суммой количества символов в каждой колонке (создан список isallnum_countresult)
  isalnum_columnslice = df[i]
  isalnum_count = isalnum_columnslice[a].isalnum()
  isalnum_countlist.append(isalnum_count)
  isalnum_sum = isalnum_sum + isalnum_countlist[a]
  a = a+1
  isalnum_countresultlist.append(isalnum_sum)
df_columns2 = pd.DataFrame(df_columns) #создаем первый датафрейм с наименованием колонок
df_dashes = pd.DataFrame(dashes_countresultlist, columns=['Тире']) #создаем датафрейм с суммой количества символов в каждой колонке
df_spaces = pd.DataFrame(spaces_countresultlist, columns=['Пробел']) #создаем датафрейм с суммой количества символов в каждой колонке
df_isalnum = pd.DataFrame(isalnum_countresultlist, columns=['Числа']) #создаем датафрейм с суммой количества символов в каждой колонке
df_dots = pd.DataFrame(dots_countresultlist, columns=['Точки'])
df_commas = pd.DataFrame(commas_countresultlist, columns=['Запятые'])
df_result = pd.concat([df_columns2, df_dashes, df_spaces, df_dots, df_commas, df_isalnum], axis=1) #теперь конкатенируем датафрейм с наименованием колонок и датафрейм с количеством символов
df_result.transpose()
# Out:
# Количество разных символов в starbucks_drinkMenu_expanded.csv
#                         0         1              2         3               4   \
# 0        Beverage_category  Beverage  Beverage_prep  Calories   Total Fat (g)
# Тире                     0         0              0         0               0
# Пробел                   0         1              1         1               1
# Точки                    0         0              0         0               0
# Запятые                  0         0              0         0               1
# Числа                    1         1              2         3               3
#
#                      5                  6             7   \
# 0        Trans Fat (g)   Saturated Fat (g)   Sodium (mg)
# Тире                  0                  0             0
# Пробел                1                  1             1
# Точки                 0                  0             0
# Запятые               2                  3             3
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Kaggle/Starbucks/Downloaded/starbucks_drinkMenu_expanded.csv')
simbols_count = df.astype(str)
simbols_count2 = simbols_count.columns.tolist() # список с наименованиями колонок
commas_countresult = []
#commas_count = pd.DataFrame([simbols_count['Trans Fat (g)'].str.count(',')])
#for i in simbols_count2: #цикл для создания списка с суммой количества символов в каждой колонке (создан список space_countresult)
#  commas_count = simbols_count[i].str.count(',')
#  commas_countsum = commas_count.sum()
#  commas_countresult.append(commas_countsum)
#commas_count = simbols_count['Trans Fat (g) '].str.count('-')
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 237    0
# 238    0
# 239    0
# 240    0
# 241    0
# Name: Trans Fat (g) , Length: 242, dtype: int64

# %%
asdf = ['asdfff2345;lk..', 'asdffff!@@@45;lk..', 'assssdff###f2345;lk..']
qwr_list = []
qwr_sum = 0
for i in range (len(asdf)):
  wer = asdf[i]
  qwr = wer.count('.')
  qwr_list.append(qwr)
  qwr_sum  = qwr_sum + qwr_list[i]
print(qwr_sum)
# Out:
# 6

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Kaggle/Starbucks/Downloaded/starbucks_drinkMenu_expanded.csv')
print('Количество разных символов в starbucks_drinkMenu_expanded.csv')
a = 0
dash_countlist = []
dash_countresult = []
dash_columnsum = 0
dash_sum = 0
df_columns = df.columns # список с наименованиями колонок
df_columns2 = pd.DataFrame(df_columns)
# for i in simbols_count2: #цикл для создания списка с суммой количества символов в каждой колонке (создан список dash_countresult)
#   dash_column = df[i]
#   dash_count = dash_column[a].count('-') #здесь проверяется каждая ячейка в колонке simbols_count[i]
#   a = a+1
#   dash_countlist.append(dash_count) #создается список из количества найденых символов в каждой ячейке
#   dash_columnsum = dash_columnsum + dash_countlist[i]
#   dash_countresult = dash_countresult.append(dash_columnsum)
# dash_countresult
df_columns2
# Out:
# Количество разных символов в starbucks_drinkMenu_expanded.csv
#                             0
# 0           Beverage_category
# 1                    Beverage
# 2               Beverage_prep
# 3                    Calories
# 4               Total Fat (g)
# 5              Trans Fat (g)
# 6           Saturated Fat (g)
# 7                 Sodium (mg)
# 8    Total Carbohydrates (g)
# 9            Cholesterol (mg)
# 10          Dietary Fibre (g)
# 11                 Sugars (g)
# 12               Protein (g)
# 13          Vitamin A (% DV)
# 14           Vitamin C (% DV)
# 15            Calcium (% DV)
# 16               Iron (% DV)
# 17              Caffeine (mg)
